# %%
import dash
from dash.dependencies import Input, Output
import json
from kafka import KafkaConsumer
import folium
from dash import Dash, dcc, html
import dash_bootstrap_components as dbc
import threading

# Initialize the Dash app
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# Global variable to store truck data
truck_data = []

# Function to consume truck locations from Kafka in a separate thread
def consume_truck_data():
    global truck_data
    consumer = KafkaConsumer(
        'TruckLocations',
        bootstrap_servers=['localhost:29092'],
        value_deserializer=lambda v: json.loads(v.decode('utf-8')),
        auto_offset_reset='earliest'
    )
    
    for message in consumer:
        data = message.value
        #print(f"Received data: {data}")
        
        # Check if truck data already exists; if so, update it, else append
        for i, truck in enumerate(truck_data):
            if truck['truck_id'] == data['truck_id']:
                truck_data[i] = data
                break
        else:
            truck_data.append(data)

# Start the Kafka consumer in a separate thread
consumer_thread = threading.Thread(target=consume_truck_data)
consumer_thread.daemon = True
consumer_thread.start()

# Function to generate map HTML from truck data
def generate_map():
    # Initialize the map
    folium_map = folium.Map(location=[0, 0], zoom_start=2)
    
    # Add markers for each truck
    for data in truck_data:
        folium.Marker(
            [data['location']['latitude'], data['location']['longitude']],
            popup=f"Truck {data['truck_id']}"
        ).add_to(folium_map)
    
    # Save map to HTML file
    map_file = 'map.html'
    folium_map.save(map_file)
    
    # Read map HTML content
    with open(map_file, 'r') as file:
        map_html_content = file.read()
    
    return map_html_content

# Create Dash layout
app.layout = html.Div([
    html.H1("Live Truck Map"),
    dcc.Interval(
        id='interval-component',
        interval=1000,  # Update every 3 second
        n_intervals=0
    ),
    html.Div(id='map-container')
])

# Callback to update map
@app.callback(
    dash.dependencies.Output('map-container', 'children'),
    dash.dependencies.Input('interval-component', 'n_intervals')
)
def update_map(n):
    map_html_content = generate_map()
    
    # Convert map HTML to base64 to display in Dash
    map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
    
    return html.Iframe(
        src=f'data:text/html;base64,{map_html_base64}',
        style={'width': '100%', 'height': '800px', 'border': 'none'}
    )

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=0)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_bbda358bf737ccd177e4b8279cb20ac2 {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_bbda358bf737ccd177e4b8279cb20ac2" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_bbda358bf737ccd177e4b8279cb20ac2 = L.map(\n                "map_bbda358bf737ccd177e4b8279cb20ac2",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_06fee04a4fe1efe6fe5c89b1ddce39d4 = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_06fee04a4fe1efe6fe5c89b1ddce39d4.addTo(map_bbda358bf737ccd177e4b8279cb20ac2);\n        \n    \n            var marker_bde13d89018ec08bbf50b7cc35670b7e = L.marker(\n                [45.38355129176287, 80.45207122346608],\n                {}\n            ).addTo(map_bbda358bf737ccd177e4b8279cb20ac2);\n        \n    \n        var popup_b09c86b194bc72f564c06f52a75998e2 = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_dc88e16fb72fafab3f3c5789750a930a = $(`<div id="html_dc88e16fb72fafab3f3c5789750a930a" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_b09c86b194bc72f564c06f52a75998e2.setContent(html_dc88e16fb72fafab3f3c5789750a930a);\n            \n        \n\n        marker_bde13d89018ec08bbf50b7cc35670b7e.bindPopup(popup_b09c86b194bc72f564c06f52a75998e2)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=1)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_0479c2eb2da584922c30640d935f7b24 {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_0479c2eb2da584922c30640d935f7b24" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_0479c2eb2da584922c30640d935f7b24 = L.map(\n                "map_0479c2eb2da584922c30640d935f7b24",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_19fdb5e1f5d6e39cca3b8851fe8e2024 = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_19fdb5e1f5d6e39cca3b8851fe8e2024.addTo(map_0479c2eb2da584922c30640d935f7b24);\n        \n    \n            var marker_11c76dc2e69324788396b9ee5982be51 = L.marker(\n                [-66.20867504830679, 121.45495591233856],\n                {}\n            ).addTo(map_0479c2eb2da584922c30640d935f7b24);\n        \n    \n        var popup_dd93c22c7f281545ad097c2274fd538b = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_1266d4a7e663cafc60a309cb717496e5 = $(`<div id="html_1266d4a7e663cafc60a309cb717496e5" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_dd93c22c7f281545ad097c2274fd538b.setContent(html_1266d4a7e663cafc60a309cb717496e5);\n            \n        \n\n        marker_11c76dc2e69324788396b9ee5982be51.bindPopup(popup_dd93c22c7f281545ad097c2274fd538b)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=2)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_d6e6d5408bf01aab9b2c6204bd13c956 {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_d6e6d5408bf01aab9b2c6204bd13c956" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_d6e6d5408bf01aab9b2c6204bd13c956 = L.map(\n                "map_d6e6d5408bf01aab9b2c6204bd13c956",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_82a49df4e714bbb3e4062a15a4287509 = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_82a49df4e714bbb3e4062a15a4287509.addTo(map_d6e6d5408bf01aab9b2c6204bd13c956);\n        \n    \n            var marker_1a0e6b8e761b6dbf42af280d4629a928 = L.marker(\n                [-9.459314470334064, -3.21015182102704],\n                {}\n            ).addTo(map_d6e6d5408bf01aab9b2c6204bd13c956);\n        \n    \n        var popup_6c117b8e6fa898733d43dd26eeb8fdb6 = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_1a7ce43929e7fbe2882a587eb0b9bde6 = $(`<div id="html_1a7ce43929e7fbe2882a587eb0b9bde6" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_6c117b8e6fa898733d43dd26eeb8fdb6.setContent(html_1a7ce43929e7fbe2882a587eb0b9bde6);\n            \n        \n\n        marker_1a0e6b8e761b6dbf42af280d4629a928.bindPopup(popup_6c117b8e6fa898733d43dd26eeb8fdb6)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=3)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_568355023dcadf9094c21b0bdb28c96c {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_568355023dcadf9094c21b0bdb28c96c" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_568355023dcadf9094c21b0bdb28c96c = L.map(\n                "map_568355023dcadf9094c21b0bdb28c96c",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_9deb897d75cc96c929a2d705af8c42c6 = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_9deb897d75cc96c929a2d705af8c42c6.addTo(map_568355023dcadf9094c21b0bdb28c96c);\n        \n    \n            var marker_b349bf1ccf0c9c129784df441ca0cb35 = L.marker(\n                [-9.459314470334064, -3.21015182102704],\n                {}\n            ).addTo(map_568355023dcadf9094c21b0bdb28c96c);\n        \n    \n        var popup_264adafc3352d51eb9a25afd0829d4ed = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_bd0d33098a11c200ccc23523c57f23a0 = $(`<div id="html_bd0d33098a11c200ccc23523c57f23a0" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_264adafc3352d51eb9a25afd0829d4ed.setContent(html_bd0d33098a11c200ccc23523c57f23a0);\n            \n        \n\n        marker_b349bf1ccf0c9c129784df441ca0cb35.bindPopup(popup_264adafc3352d51eb9a25afd0829d4ed)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=4)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_e363c458d1029d0f3ddef60708914657 {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_e363c458d1029d0f3ddef60708914657" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_e363c458d1029d0f3ddef60708914657 = L.map(\n                "map_e363c458d1029d0f3ddef60708914657",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_0d9b28d76ccc925315f858a787051ede = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_0d9b28d76ccc925315f858a787051ede.addTo(map_e363c458d1029d0f3ddef60708914657);\n        \n    \n            var marker_a692764d4031e4efd8306c403671700c = L.marker(\n                [37.70666951391388, 100.69810353477067],\n                {}\n            ).addTo(map_e363c458d1029d0f3ddef60708914657);\n        \n    \n        var popup_28ddd7e7cdd981c391e20ed33c036592 = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_93972f782ad1dbd4a653dec970cd0300 = $(`<div id="html_93972f782ad1dbd4a653dec970cd0300" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_28ddd7e7cdd981c391e20ed33c036592.setContent(html_93972f782ad1dbd4a653dec970cd0300);\n            \n        \n\n        marker_a692764d4031e4efd8306c403671700c.bindPopup(popup_28ddd7e7cdd981c391e20ed33c036592)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=5)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_bc1f459bb3ca481832fbe95b5e6cba06 {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_bc1f459bb3ca481832fbe95b5e6cba06" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_bc1f459bb3ca481832fbe95b5e6cba06 = L.map(\n                "map_bc1f459bb3ca481832fbe95b5e6cba06",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_2a64a8c1a158eecfda6bdc67e826ef65 = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_2a64a8c1a158eecfda6bdc67e826ef65.addTo(map_bc1f459bb3ca481832fbe95b5e6cba06);\n        \n    \n            var marker_44b37ac3c671ac2af28ecf57e2991c8b = L.marker(\n                [41.73762045776826, 10.350278476644974],\n                {}\n            ).addTo(map_bc1f459bb3ca481832fbe95b5e6cba06);\n        \n    \n        var popup_508204987d51ef1139b509a019838441 = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_98ae2913705eb429471aaf15bd123b9b = $(`<div id="html_98ae2913705eb429471aaf15bd123b9b" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_508204987d51ef1139b509a019838441.setContent(html_98ae2913705eb429471aaf15bd123b9b);\n            \n        \n\n        marker_44b37ac3c671ac2af28ecf57e2991c8b.bindPopup(popup_508204987d51ef1139b509a019838441)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=6)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_52ff64d18be85a0e05e70f33ef0e2cbf {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_52ff64d18be85a0e05e70f33ef0e2cbf" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_52ff64d18be85a0e05e70f33ef0e2cbf = L.map(\n                "map_52ff64d18be85a0e05e70f33ef0e2cbf",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_08e6d0f636254d815b7ff1d6dcd04733 = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_08e6d0f636254d815b7ff1d6dcd04733.addTo(map_52ff64d18be85a0e05e70f33ef0e2cbf);\n        \n    \n            var marker_3812e1e0580adcb2f55dc628aed8d3fe = L.marker(\n                [88.0108901300575, 67.64546550311266],\n                {}\n            ).addTo(map_52ff64d18be85a0e05e70f33ef0e2cbf);\n        \n    \n        var popup_34d4bd899fd204c0aa0c5495d06ee33a = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_249a1d9e030446f7eedf5b8a92282d6a = $(`<div id="html_249a1d9e030446f7eedf5b8a92282d6a" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_34d4bd899fd204c0aa0c5495d06ee33a.setContent(html_249a1d9e030446f7eedf5b8a92282d6a);\n            \n        \n\n        marker_3812e1e0580adcb2f55dc628aed8d3fe.bindPopup(popup_34d4bd899fd204c0aa0c5495d06ee33a)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=7)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_864cb4e8a79fed36b9445c858c4af8db {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_864cb4e8a79fed36b9445c858c4af8db" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_864cb4e8a79fed36b9445c858c4af8db = L.map(\n                "map_864cb4e8a79fed36b9445c858c4af8db",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_0e43e5e5af38ea7b5b19c94d698784d2 = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_0e43e5e5af38ea7b5b19c94d698784d2.addTo(map_864cb4e8a79fed36b9445c858c4af8db);\n        \n    \n            var marker_630dd05bac98b298514374e04e26c61b = L.marker(\n                [-58.75198063857394, -123.79642460770438],\n                {}\n            ).addTo(map_864cb4e8a79fed36b9445c858c4af8db);\n        \n    \n        var popup_e504afe710cc1ef7c96d06dfd4da1355 = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_9a54b83ac758652656236c58a9652a19 = $(`<div id="html_9a54b83ac758652656236c58a9652a19" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_e504afe710cc1ef7c96d06dfd4da1355.setContent(html_9a54b83ac758652656236c58a9652a19);\n            \n        \n\n        marker_630dd05bac98b298514374e04e26c61b.bindPopup(popup_e504afe710cc1ef7c96d06dfd4da1355)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=8)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_c31a0bd9185800a0e12f09e86a9a3ae1 {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_c31a0bd9185800a0e12f09e86a9a3ae1" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_c31a0bd9185800a0e12f09e86a9a3ae1 = L.map(\n                "map_c31a0bd9185800a0e12f09e86a9a3ae1",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_37d3a4ba8beb18b92abf14b95af7a54a = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_37d3a4ba8beb18b92abf14b95af7a54a.addTo(map_c31a0bd9185800a0e12f09e86a9a3ae1);\n        \n    \n            var marker_d1ffb39d5ae8439400bac318024ab467 = L.marker(\n                [48.18561336429349, -136.76675821716668],\n                {}\n            ).addTo(map_c31a0bd9185800a0e12f09e86a9a3ae1);\n        \n    \n        var popup_b91b72977845d631de440144263adf15 = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_20d6b743bf32a9c1ff0ee24f183948e2 = $(`<div id="html_20d6b743bf32a9c1ff0ee24f183948e2" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_b91b72977845d631de440144263adf15.setContent(html_20d6b743bf32a9c1ff0ee24f183948e2);\n            \n        \n\n        marker_d1ffb39d5ae8439400bac318024ab467.bindPopup(popup_b91b72977845d631de440144263adf15)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=9)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_d09203dea84e2f0b825cab586d9012f3 {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_d09203dea84e2f0b825cab586d9012f3" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_d09203dea84e2f0b825cab586d9012f3 = L.map(\n                "map_d09203dea84e2f0b825cab586d9012f3",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_d1f616ad429e1ff9acd61ab640bd2d7f = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_d1f616ad429e1ff9acd61ab640bd2d7f.addTo(map_d09203dea84e2f0b825cab586d9012f3);\n        \n    \n            var marker_05621643f7769df84bb1ecbfadad4e55 = L.marker(\n                [-54.719180150331255, 5.6994530427431584],\n                {}\n            ).addTo(map_d09203dea84e2f0b825cab586d9012f3);\n        \n    \n        var popup_e28844001c1ac5a88246b33bc34da042 = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_af52f486e72c5dd6db80c406a7255a0a = $(`<div id="html_af52f486e72c5dd6db80c406a7255a0a" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_e28844001c1ac5a88246b33bc34da042.setContent(html_af52f486e72c5dd6db80c406a7255a0a);\n            \n        \n\n        marker_05621643f7769df84bb1ecbfadad4e55.bindPopup(popup_e28844001c1ac5a88246b33bc34da042)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=10)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
# ...
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=74)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_fe9e1f8f109f99e5c86ec37e72a9eb39 {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_fe9e1f8f109f99e5c86ec37e72a9eb39" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_fe9e1f8f109f99e5c86ec37e72a9eb39 = L.map(\n                "map_fe9e1f8f109f99e5c86ec37e72a9eb39",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_7a55425fb11d205769dad3bf5b154327 = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_7a55425fb11d205769dad3bf5b154327.addTo(map_fe9e1f8f109f99e5c86ec37e72a9eb39);\n        \n    \n            var marker_400595f1f3e9285846a3413f2a6b6528 = L.marker(\n                [-38.910207716894874, 69.92134098065424],\n                {}\n            ).addTo(map_fe9e1f8f109f99e5c86ec37e72a9eb39);\n        \n    \n        var popup_7cc50e57fb45015c5677c67f26f7ef36 = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_cfbdaef78c37ad107bf3a97636af5127 = $(`<div id="html_cfbdaef78c37ad107bf3a97636af5127" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_7cc50e57fb45015c5677c67f26f7ef36.setContent(html_cfbdaef78c37ad107bf3a97636af5127);\n            \n        \n\n        marker_400595f1f3e9285846a3413f2a6b6528.bindPopup(popup_7cc50e57fb45015c5677c67f26f7ef36)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=75)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_47cc6d197a0881b255e63f4b758ee6da {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_47cc6d197a0881b255e63f4b758ee6da" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_47cc6d197a0881b255e63f4b758ee6da = L.map(\n                "map_47cc6d197a0881b255e63f4b758ee6da",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_3f10f5eabdc801fccab4351a13871b07 = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_3f10f5eabdc801fccab4351a13871b07.addTo(map_47cc6d197a0881b255e63f4b758ee6da);\n        \n    \n            var marker_2502a4a283356e0b9909591bd16a75e9 = L.marker(\n                [-38.910207716894874, 69.92134098065424],\n                {}\n            ).addTo(map_47cc6d197a0881b255e63f4b758ee6da);\n        \n    \n        var popup_c529f7e11dd39e367d463f99f503ac94 = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_5ca33c2b93aa75bdfa134daf0fe6ee47 = $(`<div id="html_5ca33c2b93aa75bdfa134daf0fe6ee47" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_c529f7e11dd39e367d463f99f503ac94.setContent(html_5ca33c2b93aa75bdfa134daf0fe6ee47);\n            \n        \n\n        marker_2502a4a283356e0b9909591bd16a75e9.bindPopup(popup_c529f7e11dd39e367d463f99f503ac94)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 85, in update_map(n=76)
#      82 map_html_content = generate_map()
#      84 # Convert map HTML to base64 to display in Dash
# ---> 85 map_html_base64 = base64.b64encode(map_html_content.encode()).decode()
#         map_html_content = '<!DOCTYPE html>\n<html>\n<head>\n    \n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n        <script>\n            L_NO_TOUCH = false;\n            L_DISABLE_3D = false;\n        </script>\n    \n    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>\n    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>\n    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>\n    <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>\n    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>\n    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>\n    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>\n    \n            <meta name="viewport" content="width=device-width,\n                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n            <style>\n                #map_1a8d1cb906019afddb1352240db1dfda {\n                    position: relative;\n                    width: 100.0%;\n                    height: 100.0%;\n                    left: 0.0%;\n                    top: 0.0%;\n                }\n                .leaflet-container { font-size: 1rem; }\n            </style>\n        \n</head>\n<body>\n    \n    \n            <div class="folium-map" id="map_1a8d1cb906019afddb1352240db1dfda" ></div>\n        \n</body>\n<script>\n    \n    \n            var map_1a8d1cb906019afddb1352240db1dfda = L.map(\n                "map_1a8d1cb906019afddb1352240db1dfda",\n                {\n                    center: [0.0, 0.0],\n                    crs: L.CRS.EPSG3857,\n                    zoom: 2,\n                    zoomControl: true,\n                    preferCanvas: false,\n                }\n            );\n\n            \n\n        \n    \n            var tile_layer_17d65eedf3f9a44715edd756bafce30b = L.tileLayer(\n                "https://tile.openstreetmap.org/{z}/{x}/{y}.png",\n                {"attribution": "\\u0026copy; \\u003ca href=\\"https://www.openstreetmap.org/copyright\\"\\u003eOpenStreetMap\\u003c/a\\u003e contributors", "detectRetina": false, "maxNativeZoom": 19, "maxZoom": 19, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}\n            );\n        \n    \n            tile_layer_17d65eedf3f9a44715edd756bafce30b.addTo(map_1a8d1cb906019afddb1352240db1dfda);\n        \n    \n            var marker_b5c85b1edfb051a5e03fb2d84ebf5507 = L.marker(\n                [-38.910207716894874, 69.92134098065424],\n                {}\n            ).addTo(map_1a8d1cb906019afddb1352240db1dfda);\n        \n    \n        var popup_1e089854d2e9bd9e07a996a9e618050a = L.popup({"maxWidth": "100%"});\n\n        \n            \n                var html_0499dee4a060862f537abd64853780b9 = $(`<div id="html_0499dee4a060862f537abd64853780b9" style="width: 100.0%; height: 100.0%;">Truck 0</div>`)[0];\n                popup_1e089854d2e9bd9e07a996a9e618050a.setContent(html_0499dee4a060862f537abd64853780b9);\n            \n        \n\n        marker_b5c85b1edfb051a5e03fb2d84ebf5507.bindPopup(popup_1e089854d2e9bd9e07a996a9e618050a)\n        ;\n\n        \n    \n</script>\n</html>'
#      87 return html.Iframe(
#      88     src=f'data:text/html;base64,{map_html_base64}',
#      89     style={'width': '100%', 'height': '800px', 'border': 'none'}
#      90 )
#
# NameError: name 'base64' is not defined
